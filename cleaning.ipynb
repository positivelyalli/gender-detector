# %%
import pandas as pd
import numpy as np

# %%
names = pd.read_csv('resources\NationalNames.csv')
characters = pd.read_csv('resources\datasets_1568_2804_movie_characters_metadata.tsv', 
                           sep='\t', error_bad_lines=False, header=None, warn_bad_lines=False)
lines = pd.read_csv('resources\movie_lines.tsv', 
                           sep='\t', error_bad_lines=False, warn_bad_lines=False, header=None)
# Out:
#   File "<ipython-input-73-a57413557b46>", line 1
#     names = pd.read_csv('resources\NationalNames.csv')
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 9-10: malformed \N character escape

# %%
names['name'] = names['name'].apply(lambda x: x.upper())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-bacb11ce6d75> in <module>
# ----> 1 names['name'] = names['Name'].apply(lambda x: x.upper())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'

# %%
names = names.rename(columns={
    'Name': 'lower',
    'Gender': 'assumed_gender',
    'Count': 'name_count'
})
names = names[['Year', 'assumed_gender', 'name_count', 'name']]

# %%
names
# Out:
#          Year assumed_gender  name_count       name
# 0        1880              F        7065       MARY
# 1        1880              F        2604       ANNA
# 2        1880              F        2003       EMMA
# 3        1880              F        1939  ELIZABETH
# 4        1880              F        1746     MINNIE
# ...       ...            ...         ...        ...
# 1825428  2014              M           5     ZYKEEM
# 1825429  2014              M           5     ZYMEER
# 1825430  2014              M           5    ZYMIERE
# 1825431  2014              M           5      ZYRAN
# 1825432  2014              M           5      ZYRIN
#
# [1825433 rows x 4 columns]

# %%
question = characters[characters[4] == '?']
question = question.rename(columns={
    0: 'id',
    1: 'name',
    2: 'movie_id',
    3: 'title',
    4: 'gender',
    5: 'credit_position'
})

# %%
#question['new_gender'] = question['name'].apply(lambda x: is 'DAKOTA')
question['named_dakota']= question['name'].apply(lambda x: 'True' if x == 'Dakota' else 'False')
question
# Out:
#          id           name movie_id  ... gender credit_position named_dakota
# 1        u1          BRUCE       m0  ...      ?               ?        False
# 3        u3       CHASTITY       m0  ...      ?               ?        False
# 8        u8     MISS PERKY       m0  ...      ?               ?        False
# 10      u10         SHARON       m0  ...      ?               ?        False
# 12      u12         ALONSO       m1  ...      ?               ?        False
# ...     ...            ...      ...  ...    ...             ...          ...
# 9029  u9030       DURNFORD     m616  ...      ?               ?        False
# 9030  u9031        MELVILL     m616  ...      ?               ?        False
# 9031  u9032  NORRIS-NEWMAN     m616  ...      ?               ?        False
# 9032  u9033   STUART SMITH     m616  ...      ?               ?        False
# 9033  u9034        VEREKER     m616  ...      ?               ?        False
#
# [6008 rows x 7 columns]

# %%
name_assumptions = names.groupby(['name','assumed_gender']).agg({'name_count': ['max']})
name_assumptions = name_assumptions.reset_index()

# %%
cols = name_assumptions.columns.droplevel(1)

# %%
name_assumptions.columns = cols

# %%
name_assumptions
# Out:
#          name assumed_gender  name_count
# 0       AARON              M       145.0
# 1          AB              M         6.0
# 2         ABB              M         6.0
# 3       ABBIE              F       140.0
# 4       ABBIE              M         8.0
# ...       ...            ...         ...
# 7305     ZUMA              F        10.0
# 7306     ZURA              F         6.0
# 7307  ZYGMUND              M         5.0
# 7308   ZYLPHA              F         8.0
# 7309  ZYLPHIA              F         6.0
#
# [7310 rows x 3 columns]

# %%
name_assumptions = name_assumptions.drop_duplicates(subset='name', keep="last")

# %%
df = question.merge(name_assumptions, on='name', how='left')

# %%
df = df.fillna('?')

# %%
question_df = df[df['assumed_gender'] == '?']
question_df
# Out:
#          id           name movie_id                       title gender  \
# 2        u8     MISS PERKY       m0  10 things i hate about you      ?
# 5       u13         AROJAZ       m1  1492: conquest of paradise      ?
# 7       u15      BOBADILLA       m1  1492: conquest of paradise      ?
# 10      u20         MENDEZ       m1  1492: conquest of paradise      ?
# 11      u21         MOXICA       m1  1492: conquest of paradise      ?
# ...     ...            ...      ...                         ...    ...
# 6003  u9030       DURNFORD     m616                   zulu dawn      ?
# 6004  u9031        MELVILL     m616                   zulu dawn      ?
# 6005  u9032  NORRIS-NEWMAN     m616                   zulu dawn      ?
# 6006  u9033   STUART SMITH     m616                   zulu dawn      ?
# 6007  u9034        VEREKER     m616                   zulu dawn      ?
#
#      credit_position named_dakota assumed_gender name_count
# 2                  ?        False              ?          ?
# 5                  ?        False              ?          ?
# 7                  ?        False              ?          ?
# 10                 ?        False              ?          ?
# 11                 ?        False              ?          ?
# ...              ...          ...            ...        ...
# 6003               ?        False              ?          ?
# 6004               ?        False              ?          ?
# 6005               ?        False              ?          ?
# 6006               ?        False              ?          ?
# 6007               ?        False              ?          ?
#
# [3016 rows x 9 columns]

# %%
def assign_gender(n):
    women = ['MRS', 'LADY', 'MS ', 'MISS', 'WOMAN', 'GIRL', 'CHICK', 'MADAM', 'MADAME', 'SENIORITA', 'SENORA',
            'MISTRESS', 'FEMALE', 'MOTHER', 'MOM', 'GRANDDAUGHTER', 'NIECE', 'AUNT', 'SISTER', 'DAUGHTER',
            'BROAD', 'DUCHESS', 'DAME', 'GENTLEWOMAN', 'QUEEN', 'CRONE', ' HAG', 'GAL', 'MAMA', 'MOMMA', 'BITCH',
            'MISSUS', 'EMPRESS', 'BARONESS', 'NOBLEWOMAN', 'GRANNY', 'NONNA', 'NUN', 'MRS.','MS.', 'FRAU','WIFE',
            'WIFEY', 'BRIDE']
    men = ['MR ', 'SENOR', 'MAN', 'GUY', 'DUDE', 'MISTER', 'BOY', 'MALE', 'BROTHER', 'HUSBAND', 'GENTLEMAN',
          'FATHER', 'DAD', 'GRANDSON', 'GRANDFATHER', 'NEPHEW', 'UNCLE', 'BARON', 'KNIGHT', 'EMPEROR', 'NOBLEMAN',
          'DADDY', 'PAPI', 'PAPA', 'GRANDPA', 'GRAMPS', 'CHAP', 'LAD', 'GEEZER', 'BLOKE', 'SIR', 'MR.', 'HUBBY','GROOM',
          'HERR']
    
    gender = '?'
    
    for x in women:
        if x in n:
            gender = 'F'
            
    for x in men:
        if x in n:
            gender = 'M'
            
    return gender

# %%
assign_gender('MISS PERKY')
# Out:
# 'F'

# %%
question_df['assumed_gender'] = question_df['name'].apply(assign_gender)
# Out:
# C:\Users\positivelyalli\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
question_df.assumed_gender.value_counts()
# Out:
# ?    2316
# M     473
# F     227
# Name: assumed_gender, dtype: int64

# %%
question_df[question_df.assumed_gender == '?']
# Out:
#          id          name movie_id                       title gender  \
# 5       u13        AROJAZ       m1  1492: conquest of paradise      ?
# 7       u15     BOBADILLA       m1  1492: conquest of paradise      ?
# 10      u20        MENDEZ       m1  1492: conquest of paradise      ?
# 11      u21        MOXICA       m1  1492: conquest of paradise      ?
# 12      u22        PINZON       m1  1492: conquest of paradise      ?
# ...     ...           ...      ...                         ...    ...
# 6002  u9029      CREALOCK     m616                   zulu dawn      ?
# 6003  u9030      DURNFORD     m616                   zulu dawn      ?
# 6004  u9031       MELVILL     m616                   zulu dawn      ?
# 6006  u9033  STUART SMITH     m616                   zulu dawn      ?
# 6007  u9034       VEREKER     m616                   zulu dawn      ?
#
#      credit_position named_dakota assumed_gender name_count
# 5                  ?        False              ?          ?
# 7                  ?        False              ?          ?
# 10                 ?        False              ?          ?
# 11                 ?        False              ?          ?
# 12                 ?        False              ?          ?
# ...              ...          ...            ...        ...
# 6002               ?        False              ?          ?
# 6003               ?        False              ?          ?
# 6004               ?        False              ?          ?
# 6006               ?        False              ?          ?
# 6007               ?        False              ?          ?
#
# [2316 rows x 9 columns]

# %%
question_df[question_df.assumed_gender == '?']
# Out:
#          id          name movie_id                       title gender  \
# 5       u13        AROJAZ       m1  1492: conquest of paradise      ?
# 7       u15     BOBADILLA       m1  1492: conquest of paradise      ?
# 10      u20        MENDEZ       m1  1492: conquest of paradise      ?
# 11      u21        MOXICA       m1  1492: conquest of paradise      ?
# 12      u22        PINZON       m1  1492: conquest of paradise      ?
# ...     ...           ...      ...                         ...    ...
# 6002  u9029      CREALOCK     m616                   zulu dawn      ?
# 6003  u9030      DURNFORD     m616                   zulu dawn      ?
# 6004  u9031       MELVILL     m616                   zulu dawn      ?
# 6006  u9033  STUART SMITH     m616                   zulu dawn      ?
# 6007  u9034       VEREKER     m616                   zulu dawn      ?
#
#      credit_position named_dakota assumed_gender name_count
# 5                  ?        False              ?          ?
# 7                  ?        False              ?          ?
# 10                 ?        False              ?          ?
# 11                 ?        False              ?          ?
# 12                 ?        False              ?          ?
# ...              ...          ...            ...        ...
# 6002               ?        False              ?          ?
# 6003               ?        False              ?          ?
# 6004               ?        False              ?          ?
# 6006               ?        False              ?          ?
# 6007               ?        False              ?          ?
#
# [2316 rows x 9 columns]

# %%
pd.set_option('display.max_rows', 25)

# %%
name_assumptions.count()
name_assumptions[name_assumptions.name == 'ALEX']
# Out:
#       name assumed_gender  name_count
# 3233  ALEX              M        7636

# %%
female_names = name_assumptions[name_assumptions.assumed_gender == 'F']
female_names.head()
# Out:
#        name assumed_gender  name_count
# 6      ABBY              F        12.0
# 9   ABELINA              F         5.0
# 11  ABIGAIL              F        21.0
# 18    ACHSA              F         7.0
# 19   ACHSAH              F         6.0

# %%
male_names = name_assumptions[name_assumptions.assumed_gender == 'M']
male_names.head()
# Out:
#      name assumed_gender  name_count
# 0   AARON              M       145.0
# 1      AB              M         6.0
# 2     ABB              M         6.0
# 4   ABBIE              M         8.0
# 5  ABBOTT              M         6.0

# %%
question_df.assumed_gender
# Out:
# 2       F
# 5       ?
# 7       ?
# 10      ?
# 11      ?
#        ..
# 6003    ?
# 6004    ?
# 6005    M
# 6006    ?
# 6007    ?
# Name: assumed_gender, Length: 3016, dtype: object

# %%
def assign_namesg(row):
    women = female_names.name.to_list() 
    men = male_names.name.to_list()
    gendered_f = ['MRS', 'LADY', 'MS ', 'MISS', 'WOMAN', 'GIRL', 'CHICK', 'MADAM', 'MADAME', 'SENIORITA', 'SENORA',
            'MISTRESS', 'FEMALE', 'MOTHER', 'MOM', 'GRANDDAUGHTER', 'NIECE', 'AUNT', 'SISTER', 'DAUGHTER',
            'BROAD', 'DUCHESS', 'DAME', 'GENTLEWOMAN', 'QUEEN', 'CRONE', ' HAG', 'GAL', 'MAMA', 'MOMMA', 'BITCH',
            'MISSUS', 'EMPRESS', 'BARONESS', 'NOBLEWOMAN', 'GRANNY', 'NONNA', 'NUN', 'MRS.','MS.', 'FRAU','WIFE',
            'WIFEY', 'BRIDE']
    gendered_m = ['MR ', 'SENOR', 'MAN', 'GUY', 'DUDE', 'MISTER', 'BOY', 'MALE', 'BROTHER', 'HUSBAND', 'GENTLEMAN',
          'FATHER', 'DAD', 'GRANDSON', 'GRANDFATHER', 'NEPHEW', 'UNCLE', 'BARON', 'KNIGHT', 'EMPEROR', 'NOBLEMAN',
          'DADDY', 'PAPI', 'PAPA', 'GRANDPA', 'GRAMPS', 'CHAP', 'LAD', 'GEEZER', 'BLOKE', 'SIR', 'MR.', 'HUBBY','GROOM',
          'HERR']
    
    gender = row['gender']
    name = row['name']
    try:
      if row['gender'] == '?':
          
          for x in women:
              if x == row['name']:
                  gender = 'F'
              

          for x in men:
              if x == row['name']:
                  gender = 'M'
                  
      if row['gender'] == '?':
          
          for x in gendered_f:
              if x in row['name']:
                  gender = 'F'
          
          for x in gendered_m:
              if x in row['name']:
                  gender = 'M'
      
      print(f'Name is {name}, Gender is {gender}')    

    except:
        print(name)
        print('Something went wrong.')    
    return gender

# %%
question_df['assumed_gender'] = question_df['name'].apply(assign_namesg)
question_df.head()
# Out:
# C:\Users\positivelyalli\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      id        name movie_id                       title gender  \
# 2    u8  MISS PERKY       m0  10 things i hate about you      ?
# 5   u13      AROJAZ       m1  1492: conquest of paradise      ?
# 7   u15   BOBADILLA       m1  1492: conquest of paradise      ?
# 10  u20      MENDEZ       m1  1492: conquest of paradise      ?
# 11  u21      MOXICA       m1  1492: conquest of paradise      ?
#
#    credit_position named_dakota assumed_gender name_count
# 2                ?        False              M          ?
# 5                ?        False              M          ?
# 7                ?        False              M          ?
# 10               ?        False              M          ?
# 11               ?        False              M          ?

# %%
lines.head()
# Out:
#        0   1   2        3             4
# 0  L1045  u0  m0   BIANCA  They do not!
# 1  L1044  u2  m0  CAMERON   They do to!
# 2   L985  u0  m0   BIANCA    I hope so.
# 3   L984  u2  m0  CAMERON     She okay?
# 4   L925  u0  m0   BIANCA     Let's go.

# %%
characters.head()
# Out:
#     0         1   2                           3  4  5
# 0  u0    BIANCA  m0  10 things i hate about you  f  4
# 1  u1     BRUCE  m0  10 things i hate about you  ?  ?
# 2  u2   CAMERON  m0  10 things i hate about you  m  3
# 3  u3  CHASTITY  m0  10 things i hate about you  ?  ?
# 4  u4      JOEY  m0  10 things i hate about you  m  6

# %%
characters_df = characters.rename(columns={
    0: 'id',
    1: 'name',
    2: 'movie_id',
    3: 'title',
    4: 'gender',
    5: 'credit_position'
})

characters_df
# Out:
#          id           name  ... gender credit_position
# 0        u0         BIANCA  ...      f               4
# 1        u1          BRUCE  ...      ?               ?
# 2        u2        CAMERON  ...      m               3
# 3        u3       CHASTITY  ...      ?               ?
# 4        u4           JOEY  ...      m               6
# ...     ...            ...  ...    ...             ...
# 9029  u9030       DURNFORD  ...      ?               ?
# 9030  u9031        MELVILL  ...      ?               ?
# 9031  u9032  NORRIS-NEWMAN  ...      ?               ?
# 9032  u9033   STUART SMITH  ...      ?               ?
# 9033  u9034        VEREKER  ...      ?               ?
#
# [9034 rows x 6 columns]

# %%
pd.set_option('display.max_rows', 100)
characters_df.name.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0              BIANCA
# 1               BRUCE
# 2             CAMERON
# 3            CHASTITY
# 4                JOEY
#             ...
# 9029         DURNFORD
# 9030          MELVILL
# 9031    NORRIS-NEWMAN
# 9032     STUART SMITH
# 9033          VEREKER
# Name: name, Length: 9034, dtype: object>

# %%
characters_df.gender = characters_df.apply(assign_namesg, axis = 1)
characters_df.head()

# %%
characters_df.head()
# Out:
#    id      name movie_id                       title gender credit_position
# 0  u0    BIANCA       m0  10 things i hate about you      f               4
# 1  u1     BRUCE       m0  10 things i hate about you      M               ?
# 2  u2   CAMERON       m0  10 things i hate about you      m               3
# 3  u3  CHASTITY       m0  10 things i hate about you      ?               ?
# 4  u4      JOEY       m0  10 things i hate about you      m               6

# %%
characters_df.groupby('gender').count()
# Out:
#           id  name  movie_id  title  credit_position
# gender
# ?       3161  3159      3161   3161             3161
# F        628   628       628    628              628
# M       2408  2408      2408   2408             2408
# f        921   921       921    921              921
# m       1899  1899      1899   1899             1899

# %%
characters_df.gender = characters_df.gender.str.upper()

# %%
characters_df.groupby('gender').count()
# Out:
#           id  name  movie_id  title  credit_position
# gender
# ?       3161  3159      3161   3161             3161
# F       1549  1549      1549   1549             1549
# M       4307  4307      4307   4307             4307

# %%
# characters_df.to_csv('characters_updated.csv')
characters_df.head()
character_gender = characters_df[['id', 'gender']]
# Out:
#    id      name movie_id                       title gender credit_position
# 0  u0    BIANCA       m0  10 things i hate about you      f               4
# 1  u1     BRUCE       m0  10 things i hate about you      ?               ?
# 2  u2   CAMERON       m0  10 things i hate about you      m               3
# 3  u3  CHASTITY       m0  10 things i hate about you      ?               ?
# 4  u4      JOEY       m0  10 things i hate about you      m               6

# %%
lines = lines.rename(columns={
   'character_id': 'id',
})
lines.head()
# Out:
#   line_id  id movie_id     name          line
# 0   L1045  u0       m0   BIANCA  They do not!
# 1   L1044  u2       m0  CAMERON   They do to!
# 2    L985  u0       m0   BIANCA    I hope so.
# 3    L984  u2       m0  CAMERON     She okay?
# 4    L925  u0       m0   BIANCA     Let's go.

# %%
characters_updated = lines.merge(characters_df, how='left', on='id')
characters_updated.head()
# Out:
#   line_id  id movie_id_x   name_x          line   name_y movie_id_y  \
# 0   L1045  u0         m0   BIANCA  They do not!   BIANCA         m0
# 1   L1044  u2         m0  CAMERON   They do to!  CAMERON         m0
# 2    L985  u0         m0   BIANCA    I hope so.   BIANCA         m0
# 3    L984  u2         m0  CAMERON     She okay?  CAMERON         m0
# 4    L925  u0         m0   BIANCA     Let's go.   BIANCA         m0
#
#                         title gender credit_position
# 0  10 things i hate about you      f               4
# 1  10 things i hate about you      m               3
# 2  10 things i hate about you      f               4
# 3  10 things i hate about you      m               3
# 4  10 things i hate about you      f               4

# %%
# characters_updated = characters_updated[['line_id', 'id', 'movie_id_x', 'name_x', 'line', 'title', 'gender']]
characters_updated = characters_updated.rename(columns={
    'id': 'character_id',
    'movie_id_x': 'movie_id', 
    'name_x': 'name',
})
characters_updated.head()
# Out:
#   line_id character_id movie_id     name          line  \
# 0   L1045           u0       m0   BIANCA  They do not!
# 1   L1044           u2       m0  CAMERON   They do to!
# 2    L985           u0       m0   BIANCA    I hope so.
# 3    L984           u2       m0  CAMERON     She okay?
# 4    L925           u0       m0   BIANCA     Let's go.
#
#                         title gender
# 0  10 things i hate about you      f
# 1  10 things i hate about you      m
# 2  10 things i hate about you      f
# 3  10 things i hate about you      m
# 4  10 things i hate about you      f

# %%
# characters_updated.to_csv('characters_updated_gnd.csv', header=True)

# %%
character_gender.to_csv('character_gender.csv', header=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-4d4ba573a0a6> in <module>
# ----> 1 character_gender.to_csv('character_gender.csv', header=True)
#
# NameError: name 'character_gender' is not defined
