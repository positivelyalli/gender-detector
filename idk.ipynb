# %%
import pandas as pd
import re

# %%
lines = pd.read_csv("fixed_lines.csv")

# %%
lines.dialogue = lines.dialogue.str.upper()

# %%
lines
# Out:
#          lineId   chId   mId    chName  \
# 0         L1045     u0    m0    BIANCA
# 1         L1044     u2    m0   CAMERON
# 2          L985     u0    m0    BIANCA
# 3          L984     u2    m0   CAMERON
# 4          L925     u0    m0    BIANCA
# ...         ...    ...   ...       ...
# 293197  L666371  u9030  m616  DURNFORD
# 293198  L666370  u9034  m616   VEREKER
# 293199  L666369  u9030  m616  DURNFORD
# 293200  L666257  u9030  m616  DURNFORD
# 293201  L666256  u9034  m616   VEREKER
#
#                                                  dialogue
# 0                                            THEY DO NOT!
# 1                                             THEY DO TO!
# 2                                              I HOPE SO.
# 3                                               SHE OKAY?
# 4                                               LET'S GO.
# ...                                                   ...
# 293197  LORD CHELMSFORD SEEMS TO WANT ME TO STAY BACK ...
# ...
