# %%
#Importing dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
#Loading data into dataframes
character_df = pd.read_csv("fixed_characters.csv") #Do we need encoding ="latin-1"?
lines_df = pd.read_csv("fixed_lines.csv", encoding ="latin-1")

# %%
lines_df
# Out:
#         Unnamed: 0   lineId   chId   mId    chName  \
# 0                0    L1045     u0    m0    BIANCA
# 1                1    L1044     u2    m0   CAMERON
# 2                2     L985     u0    m0    BIANCA
# 3                3     L984     u2    m0   CAMERON
# 4                4     L925     u0    m0    BIANCA
# ...            ...      ...    ...   ...       ...
# 292938      293197  L666371  u9030  m616  DURNFORD
# 292939      293198  L666370  u9034  m616   VEREKER
# 292940      293199  L666369  u9030  m616  DURNFORD
# 292941      293200  L666257  u9030  m616  DURNFORD
# 292942      293201  L666256  u9034  m616   VEREKER
#
#                                                  dialogue
# 0                                             They do not
# 1                                              They do to
# 2                                               I hope so
# 3                                                She okay
# 4                                                Let's go
# ...                                                   ...
# 292938  Lord Chelmsford seems to want me to stay back ...
# 292939  I'm to take the Sikali with the main column to...
# 292940                             Your orders Mr Vereker
# 292941  Good ones yes Mr Vereker Gentlemen who can rid...
# 292942  Colonel Durnford William Vereker I hear you 'v...
#
# [292943 rows x 6 columns]

# %%
character_df.head()
# Out:
#    id      name movie_id                       title gender credit_position
# 0  u0    BIANCA       m0  10 things i hate about you      f               4
# 1  u1     BRUCE       m0  10 things i hate about you      M               ?
# 2  u2   CAMERON       m0  10 things i hate about you      m               3
# 3  u3  CHASTITY       m0  10 things i hate about you      F               ?
# 4  u4      JOEY       m0  10 things i hate about you      m               6

# %%
character_df.shape
# Out:
# (9034, 6)

# %% [markdown]
# # Normalize Data

# %%
# Change all text in name to lowercase
character_df.name = character_df.name.str.lower()
character_df
# Out:
#          id           name movie_id                       title gender  \
# 0        u0         bianca       m0  10 things i hate about you      f
# 1        u1          bruce       m0  10 things i hate about you      M
# 2        u2        cameron       m0  10 things i hate about you      m
# 3        u3       chastity       m0  10 things i hate about you      F
# 4        u4           joey       m0  10 things i hate about you      m
# ...     ...            ...      ...                         ...    ...
# 9029  u9030       durnford     m616                   zulu dawn      ?
# 9030  u9031        melvill     m616                   zulu dawn      ?
# 9031  u9032  norris-newman     m616                   zulu dawn      M
# 9032  u9033   stuart smith     m616                   zulu dawn      ?
# 9033  u9034        vereker     m616                   zulu dawn      ?
#
#      credit_position
# 0                  4
# 1                  ?
# 2                  3
# 3                  ?
# 4                  6
# ...              ...
# 9029               ?
# 9030               ?
# 9031               ?
# 9032               ?
# 9033               ?
#
# [9034 rows x 6 columns]

# %%
# Fix the tabs and spacing in rows with errors
def reset_tabs(row):
  character_id = row['id']
  name = row['name']
  movie_id = row['movie_id']
  title = row['title']
  gender = row['gender']
  credit_position = row['credit_position']
  if '\t' in character_id:
    lst = character_id.split('\t')
    character_id = lst[0]
    name = lst[1]
    movie_id = lst[2]
    title = lst[3]
    gender = lst[4]
    credit_position = lst[5]
    print(character_id)
  series = pd.Series([character_id, name, movie_id, title, gender, credit_position])
  return series

# %%
character_df = character_df.apply(reset_tabs, axis=1)
# Out:
# u1602
# u1866
# u4660
# u4664
# u5011
# u6736
# u6737
# u6738
# u6739
# u6740
# u6741
# u6742
# u6743
# u7230
# u7845
# u7914
# u7917

# %%
character_df
character_df[character_df[1].isnull()]
character_df.dropna()
# Out:
#           0              1     2                           3  4  5
# 0        u0         bianca    m0  10 things i hate about you  f  4
# 1        u1          bruce    m0  10 things i hate about you  M  ?
# 2        u2        cameron    m0  10 things i hate about you  m  3
# 3        u3       chastity    m0  10 things i hate about you  F  ?
# 4        u4           joey    m0  10 things i hate about you  m  6
# ...     ...            ...   ...                         ... .. ..
# 9029  u9030       durnford  m616                   zulu dawn  ?  ?
# 9030  u9031        melvill  m616                   zulu dawn  ?  ?
# 9031  u9032  norris-newman  m616                   zulu dawn  M  ?
# 9032  u9033   stuart smith  m616                   zulu dawn  ?  ?
# 9033  u9034        vereker  m616                   zulu dawn  ?  ?
#
# [9032 rows x 6 columns]

# %%
character_df = character_df.rename(columns={
    0: 'id',
    1: 'name',
    2: 'movie_id',
    3: 'title',
    4: 'gender',
    5: 'credit_position'
})

character_df
# Out:
#          id           name movie_id                       title gender  \
# 0        u0         bianca       m0  10 things i hate about you      f
# 1        u1          bruce       m0  10 things i hate about you      M
# 2        u2        cameron       m0  10 things i hate about you      m
# 3        u3       chastity       m0  10 things i hate about you      F
# 4        u4           joey       m0  10 things i hate about you      m
# ...     ...            ...      ...                         ...    ...
# 9029  u9030       durnford     m616                   zulu dawn      ?
# 9030  u9031        melvill     m616                   zulu dawn      ?
# 9031  u9032  norris-newman     m616                   zulu dawn      M
# 9032  u9033   stuart smith     m616                   zulu dawn      ?
# 9033  u9034        vereker     m616                   zulu dawn      ?
#
#      credit_position
# 0                  4
# 1                  ?
# 2                  3
# 3                  ?
# 4                  6
# ...              ...
# 9029               ?
# 9030               ?
# 9031               ?
# 9032               ?
# 9033               ?
#
# [9034 rows x 6 columns]

# %%
character_df['gender'].value_counts()
# Out:
# M    2456
# ?    2418
# m    1899
# F    1340
# f     921
# Name: gender, dtype: int64

# %%
character_df.dtypes
# Out:
# id                 object
# name               object
# movie_id           object
# title              object
# gender             object
# credit_position    object
# dtype: object

# %%
character_df['gender'][character_df.gender == '?'] = "N"

# %%
character_df['gender'].value_counts()
# Out:
# M    2456
# N    2418
# m    1899
# F    1340
# f     921
# Name: gender, dtype: int64

# %%
character_df['gender'] = character_df['gender'].str.upper()

# %%
character_df = character_df.rename(columns={
   'id': 'chid',
})
character_df
# Out:
#        chid           name movie_id                       title gender  \
# 0        u0         bianca       m0  10 things i hate about you      F
# 1        u1          bruce       m0  10 things i hate about you      M
# 2        u2        cameron       m0  10 things i hate about you      M
# 3        u3       chastity       m0  10 things i hate about you      F
# 4        u4           joey       m0  10 things i hate about you      M
# ...     ...            ...      ...                         ...    ...
# 9029  u9030       durnford     m616                   zulu dawn      N
# 9030  u9031        melvill     m616                   zulu dawn      N
# 9031  u9032  norris-newman     m616                   zulu dawn      M
# 9032  u9033   stuart smith     m616                   zulu dawn      N
# 9033  u9034        vereker     m616                   zulu dawn      N
#
#      credit_position
# 0                  4
# 1                  ?
# 2                  3
# 3                  ?
# 4                  6
# ...              ...
# 9029               ?
# 9030               ?
# 9031               ?
# 9032               ?
# 9033               ?
#
# [9034 rows x 6 columns]

# %%
gender_count = character_df['gender'].value_counts()
gender_count
# Out:
# M    4355
# N    2418
# F    2261
# Name: gender, dtype: int64

# %%
#Cleaning all of the hyphens out of the dialogue
newlines_df = lines_df
newlines_df['dialogue'] = newlines_df['dialogue'].replace('-', ' ', regex=True).astype(str)
newlines_df
# Out:
#         Unnamed: 0   lineId   chId   mId    chName  \
# 0                0    L1045     u0    m0    BIANCA
# 1                1    L1044     u2    m0   CAMERON
# 2                2     L985     u0    m0    BIANCA
# 3                3     L984     u2    m0   CAMERON
# 4                4     L925     u0    m0    BIANCA
# ...            ...      ...    ...   ...       ...
# 292938      293197  L666371  u9030  m616  DURNFORD
# 292939      293198  L666370  u9034  m616   VEREKER
# 292940      293199  L666369  u9030  m616  DURNFORD
# 292941      293200  L666257  u9030  m616  DURNFORD
# 292942      293201  L666256  u9034  m616   VEREKER
#
#                                                  dialogue
# 0                                             They do not
# 1                                              They do to
# 2                                               I hope so
# 3                                                She okay
# 4                                                Let's go
# ...                                                   ...
# 292938  Lord Chelmsford seems to want me to stay back ...
# 292939  I'm to take the Sikali with the main column to...
# 292940                             Your orders Mr Vereker
# 292941  Good ones yes Mr Vereker Gentlemen who can rid...
# 292942  Colonel Durnford William Vereker I hear you 'v...
#
# [292943 rows x 6 columns]

# %%
#Cleaning all of the double hyphens out of the dialogue
newlines_df['dialogue'] = newlines_df['dialogue'].replace('--', ' ', regex=True).astype(str)
newlines_df
# Out:
#         Unnamed: 0   lineId   chId   mId    chName  \
# 0                0    L1045     u0    m0    BIANCA
# 1                1    L1044     u2    m0   CAMERON
# 2                2     L985     u0    m0    BIANCA
# 3                3     L984     u2    m0   CAMERON
# 4                4     L925     u0    m0    BIANCA
# ...            ...      ...    ...   ...       ...
# 292938      293197  L666371  u9030  m616  DURNFORD
# 292939      293198  L666370  u9034  m616   VEREKER
# 292940      293199  L666369  u9030  m616  DURNFORD
# 292941      293200  L666257  u9030  m616  DURNFORD
# 292942      293201  L666256  u9034  m616   VEREKER
#
#                                                  dialogue
# 0                                             They do not
# 1                                              They do to
# 2                                               I hope so
# 3                                                She okay
# 4                                                Let's go
# ...                                                   ...
# 292938  Lord Chelmsford seems to want me to stay back ...
# 292939  I'm to take the Sikali with the main column to...
# 292940                             Your orders Mr Vereker
# 292941  Good ones yes Mr Vereker Gentlemen who can rid...
# 292942  Colonel Durnford William Vereker I hear you 'v...
#
# [292943 rows x 6 columns]

# %%
# testing to see if they were replaced
newlines_df['dialogue'].str.findall('--').value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         []
# 1         []
# 2         []
# 3         []
# 4         []
#           ..
# 292938    []
# 292939    []
# 292940    []
# 292941    []
# 292942    []
# Name: dialogue, Length: 292943, dtype: object>

# %%
newlines_df = newlines_df[['lineId', 'chId', 'mId', 'chName', 'dialogue']]
newlines_df
# Out:
#          lineId   chId   mId    chName  \
# 0         L1045     u0    m0    BIANCA
# 1         L1044     u2    m0   CAMERON
# 2          L985     u0    m0    BIANCA
# 3          L984     u2    m0   CAMERON
# 4          L925     u0    m0    BIANCA
# ...         ...    ...   ...       ...
# 292938  L666371  u9030  m616  DURNFORD
# 292939  L666370  u9034  m616   VEREKER
# 292940  L666369  u9030  m616  DURNFORD
# 292941  L666257  u9030  m616  DURNFORD
# 292942  L666256  u9034  m616   VEREKER
#
#                                                  dialogue
# 0                                             They do not
# 1                                              They do to
# 2                                               I hope so
# 3                                                She okay
# 4                                                Let's go
# ...                                                   ...
# 292938  Lord Chelmsford seems to want me to stay back ...
# 292939  I'm to take the Sikali with the main column to...
# 292940                             Your orders Mr Vereker
# 292941  Good ones yes Mr Vereker Gentlemen who can rid...
# 292942  Colonel Durnford William Vereker I hear you 'v...
#
# [292943 rows x 5 columns]

# %%
newlines_df = newlines_df.rename(columns={
   'chId': 'chid',
})
newlines_df
# Out:
#          lineId   chid   mId    chName  \
# 0         L1045     u0    m0    BIANCA
# 1         L1044     u2    m0   CAMERON
# 2          L985     u0    m0    BIANCA
# 3          L984     u2    m0   CAMERON
# 4          L925     u0    m0    BIANCA
# ...         ...    ...   ...       ...
# 292938  L666371  u9030  m616  DURNFORD
# 292939  L666370  u9034  m616   VEREKER
# 292940  L666369  u9030  m616  DURNFORD
# 292941  L666257  u9030  m616  DURNFORD
# 292942  L666256  u9034  m616   VEREKER
#
#                                                  dialogue
# 0                                             They do not
# 1                                              They do to
# 2                                               I hope so
# 3                                                She okay
# 4                                                Let's go
# ...                                                   ...
# 292938  Lord Chelmsford seems to want me to stay back ...
# 292939  I'm to take the Sikali with the main column to...
# 292940                             Your orders Mr Vereker
# 292941  Good ones yes Mr Vereker Gentlemen who can rid...
# 292942  Colonel Durnford William Vereker I hear you 'v...
#
# [292943 rows x 5 columns]

# %% [markdown]
# # Merge Datasets

# %%
#Merge the datasets so that every line has a gender associated with it
characterline_df = newlines_df.merge(character_df, on='chid', how='left')
characterline_df.head()
# Out:
#   lineId chid mId   chName     dialogue     name movie_id  \
# 0  L1045   u0  m0   BIANCA  They do not   bianca       m0
# 1  L1044   u2  m0  CAMERON   They do to  cameron       m0
# 2   L985   u0  m0   BIANCA    I hope so   bianca       m0
# 3   L984   u2  m0  CAMERON     She okay  cameron       m0
# 4   L925   u0  m0   BIANCA     Let's go   bianca       m0
#
#                         title gender credit_position
# 0  10 things i hate about you      F               4
# 1  10 things i hate about you      M               3
# 2  10 things i hate about you      F               4
# 3  10 things i hate about you      M               3
# 4  10 things i hate about you      F               4

# %%
#Normalize the dialogue in the new refined dataset
slim_df = characterline_df[['gender', 'dialogue']]
slim_df['dialogue'] = slim_df['dialogue'].apply(lambda x: x.lower())
slim_df
# Out:
# C:\Users\positivelyalli\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        gender                                           dialogue
# 0           F                                        they do not
# 1           M                                         they do to
# 2           F                                          i hope so
# 3           M                                           she okay
# 4           F                                           let's go
# ...       ...                                                ...
# 292938      N  lord chelmsford seems to want me to stay back ...
# 292939      N  i'm to take the sikali with the main column to...
# 292940      N                             your orders mr vereker
# 292941      N  good ones yes mr vereker gentlemen who can rid...
# 292942      N  colonel durnford william vereker i hear you 'v...
#
# [292943 rows x 2 columns]

# %%
slim_df.gender.fillna('N', inplace =True)
# Out:
# C:\Users\positivelyalli\Anaconda3\lib\site-packages\pandas\core\generic.py:6287: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
slim_df.gender.isna().sum()
# Out:
# 0

# %% [markdown]
# # Encode the gender labels

# %%
# slim_df.gender = [ 1 if each == 'f' elif each == 'M'{ slim_df.gender = 2} else 0 for each data.gender]
slim_df['gender'] = slim_df['gender'].replace('M', 0, regex=True)
slim_df['gender'] = slim_df['gender'].replace('F', 1, regex=True)
slim_df['gender'] = slim_df['gender'].replace('N', 2, regex=True)
slim_df
# Out:
# C:\Users\positivelyalli\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\positivelyalli\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\positivelyalli\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#         gender                                           dialogue
# 0            1                                        they do not
# 1            0                                         they do to
# 2            1                                          i hope so
# 3            0                                           she okay
# 4            1                                           let's go
# ...        ...                                                ...
# 292938       2  lord chelmsford seems to want me to stay back ...
# 292939       2  i'm to take the sikali with the main column to...
# 292940       2                             your orders mr vereker
# 292941       2  good ones yes mr vereker gentlemen who can rid...
# 292942       2  colonel durnford william vereker i hear you 'v...
#
# [292943 rows x 2 columns]

# %%
# slim_df['gender'] = slim_df['gender'].astype(int)
slim_df.dtypes
# Out:
# gender       int64
# dialogue    object
# dtype: object

# %%
#Looking at the counts for each gender
slim_df.gender.value_counts().values
# Out:
# array([187727,  82221,  22995], dtype=int64)

# %%
#Calculating the male/female counts - men get more than double the lines than women
# make a chart
slim_df.gender.value_counts().values[0]/slim_df.gender.value_counts().values[1]
# Out:
# 2.28320015567799

# %%
characterline_df['name'].nunique()
# Out:
# 5231

# %%
slim_df.to_csv('slim.csv')

# %% [markdown]
# # Remove Stopwords

# %%
# Remove Stopwords
import nltk
# !pip install --upgrade nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# Requirement already up-to-date: nltk in c:\users\positivelyalli\anaconda3\lib\site-packages (3.5)
# Requirement already satisfied, skipping upgrade: click in c:\users\positivelyalli\anaconda3\lib\site-packages (from nltk) (7.0)
# Requirement already satisfied, skipping upgrade: regex in c:\users\positivelyalli\anaconda3\lib\site-packages (from nltk) (2020.6.8)
# Requirement already satisfied, skipping upgrade: tqdm in c:\users\positivelyalli\anaconda3\lib\site-packages (from nltk) (4.36.1)
# Requirement already satisfied, skipping upgrade: joblib in c:\users\positivelyalli\anaconda3\lib\site-packages (from nltk) (0.13.2)
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\positivelyalli\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
type(stopwords.words('english'))
# Out:
# list

# %% [markdown]
# ### Create new stopwords set to include character names

# %%
sw = stopwords.words('english')
names = character_df['name']
names = names.to_list()

sw.extend(names)
print(sw)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'bianca', 'bruce', 'cameron', 'chastity', 'joey', 'kat', 'mandella', 'michael', 'miss perky', 'patrick', 'sharon', 'walter', 'alonso', 'arojaz', 'beatrix', 'bobadilla', 'columbus', 'fernando', 'isabel', 'marchena', 'mendez', 'moxica', 'pinzon', 'sailor', 'sanchez', 'utapan', 'cutler', 'daphne', 'duffy', 'eddie', 'emil', 'hawkins', 'honey', 'immigration officer', 'jordy', 'korfin', 'leon', 'maggie', 'max', 'milos', 'mugger', 'nicolette', 'oleg', 'robert hawkins', 'rose', 'secondary officer', 'stephen geller', 'tommy', 'vendor', 'b20', 'bowman', 'c12', 'child', 'co-pilot', 'elena', 'floyd', 'hal', 'michaels', 'miller', 'pilot', 'poole', 'smyslov', 'attendant', 'bartender', 'billy', 'candy', 'casey', 'cates', 'elaine', 'ganz', 'haden', 'hammond', 'henry', 'kehoe', 'lisa', 'luther', 'sosna', 'young cop', 'cornelius', 'david', 'diva', 'finger', 'girl', 'kommander', 'korben', 'leeloo', 'loc rhod', 'mactilburgh', 'mother', 'mugger', 'munro', 'president', 'priest', 'professor', 'secretary', 'shadow', 'staedert', 'thai', 'voice', 'zorg', 'amy', 'angry dealer', 'dino', 'dino velvet', 'director', 'eddie', 'longdale', 'male voice', 'max', 'mrs christian', 'mrs mathews', 'nun', 'politician', 'salesperson', 'welles', 'alice', 'dan', 'debbie', 'elaine', 'kristen', 'nurse', 'rick', 'sheila', 'alice', "alice's dad", 'dan', 'greta', 'jacob', 'mark', 'mrs. jordan', 'yvonne', 'carl', 'dave', 'griff', 'kent', 'reef', 'saucer voice', 'sir ian', 'wendover', 'alma', 'chick', 'hand', 'jack', 'jill', 'lariviere', 'lillian', 'lugene', 'margie', 'mel gordon', 'mrs. gordon', 'nick', 'pop', 'rolfe', 'twombley', 'wade', 'alice', 'cerallos', 'chief mechanic', 'col. carlton', 'dean', 'doherty', 'general northwood', 'gibbs', 'iraqi soldier', 'kc-135 pilot', 'kc-lo pilot', 'korshunov', 'lee', 'major caldwell', 'marshall', 'mitchell', 'rose', 'secret service agent', 'secretary', 'shepherd', 'switchboard', 'tower', 'v.p. chandler', 'commissioner', 'dunn', 'elaine', 'jimmy', 'joe', 'john', 'kruger', 'mary', 'oveur', 'porter', 'receptionist', 'rok', 'rumack', 'simon', 'stella', 'ted', 'wife', 'bernice', 'carey', 'dr. rumack', 'elaine', 'girl', 'gunderson', 'jack', 'joey', 'kramer', 'lisa', 'milton', 'mrs. hammen', 'mrs. kramer', 'murdock', 'oveur', 'randy', 'shirley', 'sister angelina', 'soldier', 'striker', 'cassandra', 'fedorchuk', 'harcourt', 'jetson', 'kipling', 'maffet', "o'neal", 'operator', 'porter', 'sykes', 'tuggle', 'warner', 'winter', 'apone', 'bishop', 'burke', 'gorman', 'hicks', 'hudson', 'lydecker', 'med-t ...

# %%
# what type is sw?
type(sw)
# Out:
# list

# %% [markdown]
# ### Sample Data to try removing stopwords and lemmatization

# %%
#Create sample data from a line of dialogue
sample_text = slim_df.dialogue[292940]
sample_text
# Out:
# 'your orders mr vereker'

# %%
#Remove the stopwords from the sample data

#download the nltk words
nltk.download('punkt')
#text  = text .split()
sample_text  = nltk.word_tokenize(sample_text )
#if we use word_tokenize instead of split it will be better
#split() = shouldn't => shouldn't
#word_tokenize() = shouldn't => shouldn't and n't separate as two word
sample_text  = [word for word in sample_text  if not word in set(sw)]
sample_text
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\positivelyalli\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['orders', 'mr']

# %%
type(sample_text)
# Out:
# list

# %%
#Stemming words or lemmatazation
import nltk 
nltk.download('wordnet')
from nltk.corpus import wordnet

lemma = nltk.WordNetLemmatizer()
sample_text = [lemma.lemmatize(word) for word in sample_text]
sample_text

# NOT WORKING - 
# TypeError: lemmatize() missing 1 required positional argument: 'word'
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\positivelyalli\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['order', 'mr']

# %%
#Stemming words
from nltk.stem.porter import PorterStemmer
porter_stemmer = PorterStemmer()

sample_text = [porter_stemmer.stem(word) for word in sample_text]
sample_text
# Out:
# ['order', 'mr']

# %%
#Turn words into one string
sample_text = " ".join(sample_text)
sample_text
# Out:
# 'order mr'

# %% [markdown]
# # Remove stopwords and stem every line of dialogue

# %%
start_time = pd.Timestamp.now()
start_time
# Out:
# Timestamp('2020-06-20 10:52:31.713659')

# %%
dialogue = []
for x in slim_df.dialogue:
    description = nltk.word_tokenize(x)
    description = [word for word in description if not word in sw]
    lemma = nltk.WordNetLemmatizer()
    description = [lemma.lemmatize(word) for word in description]
    description = " ".join(description)
    dialogue.append(description)

# %%
#
import time
dialogue_list = []

count = 1
start_time =  pd.Timestamp.now(tz='US/Pacific')
time_now = start_time
delta_time = 0
progress = 0
rate = 0
eta = 0
total_units = len(slim_df.dialogue)
time_end = 0
for dialogue in slim_df.dialogue:
    time_now =  pd.Timestamp.now(tz='US/Pacific')
    delta_time = time_now - start_time
    rate = delta_time / count
    remaining = total_units - count
    eta = remaining * rate
    time_end = (start_time + eta) #to time stamp string....
    if count %10000 == 0:
      print(str(pd.Timestamp(time_end)))
      print(count)
    if count == 10:
      print(str(pd.Timestamp(time_end)))
      print(count)
    dialogue = nltk.word_tokenize(dialogue)
    dialogue = [ word for word in dialogue if not word in set(sw)]
    lemma = nltk.WordNetLemmatizer()
    dialogue = [lemma.lemmatize(word) for word in dialogue]
    dialogue = " ".join(dialogue)
    dialogue_list.append(dialogue)
    count = count + 1
    
    
dialogue_list
# Out:
# 2020-06-20 11:06:42.965830300-07:00
# 10
# 2020-06-20 11:11:34.066091512-07:00
# 10000
# 2020-06-20 11:11:11.071816355-07:00
# 20000
# 2020-06-20 11:11:03.656701550-07:00
# 30000
# 2020-06-20 11:11:21.996837844-07:00
# 40000
# 2020-06-20 11:10:29.493668894-07:00
# 50000
# 2020-06-20 11:10:01.524816304-07:00
# 60000
# 2020-06-20 11:09:24.552417383-07:00
# 70000
# 2020-06-20 11:08:46.990594832-07:00
# 80000
# 2020-06-20 11:07:56.254606319-07:00
# 90000
# 2020-06-20 11:07:04.825857123-07:00
# 100000
# 2020-06-20 11:06:20.353485758-07:00
# 110000
# 2020-06-20 11:05:28.721032564-07:00
# 120000
# 2020-06-20 11:04:37.047999333-07:00
# 130000
# 2020-06-20 11:03:47.754877304-07:00
# 140000
# 2020-06-20 11:02:55.847998958-07:00
# 150000
# 2020-06-20 11:02:11.510312816-07:00
# 160000
# 2020-06-20 11:01:25.415733365-07:00
# 170000
# 2020-06-20 11:00:38.155938599-07:00
# 180000
# 2020-06-20 10:59:54.583215746-07:00
# 190000
# 2020-06-20 10:59:09.954301043-07:00
# 200000
# 2020-06-20 10:58:26.968154698-07:00
# 210000
# 2020-06-20 10:57:42.512113605-07:00
# 220000
# 2020-06-20 10:56:59.722828067-07:00
# 230000
# 2020-06-20 10:56:17.636868675-07:00
# 240000
# 2020-06-20 10:55:35.211851913-07:00
# 250000
# 2020-06-20 10:54:52.818483344-07:00
# 260000
# 2020-06-20 10:54:10.802315627-07:00
# 270000
# 2020-06-20 10:53:28.852454578-07:00
# 280000
# 2020-06-20 10:52:46.950119738-07:00
# 290000
# ['',
#  '',
#  '',
#  'okay',
#  "let 's go",
#  'wow',
#  "okay 're gon na need learn lie",
#  '',
#  "'m kidding know sometimes become persona n't know quit",
#  'like fear wearing pastel',
#  'real',
#  'good stuff',
#  "figured 'd get good stuff eventually",
#  'thank hear one story coiffure',
#  "endless babble 'm like boring",
#  'crap',
#  'listen crap',
#  '',
#  "guillermo say go lighter 're gon na look like extra 90210",
#  'always selfish',
#  '',
#  "'s say",
#  'well',
#  "never wanted go 'me",
#  '',
#  'looked back party always seemed occupied',
#  'ton',
#  'fun tonight',
#  'believe share instructor',
#  'know',
#  'look like thing worked tonight huh',
#  'hi',
#  "know 've ever heard say 'd dip dating smoke",
#  "'s kind like pretty one",
#  "lesbian found picture jared leto one drawer 'm pretty sure 's harboring sex tendency",
#  "'s",
#  "'m workin ' n't seem goin '",
#  "really really really wan na go ca n't unless go",
#  'sure',
#  "eber 's deep conditioner every two day never ever use blowdryer without diffuser attachment",
#  'get hair look like',
#  "'re sweet",
#  'word',
#  "counted help cause thug obviously failing n't ever going date",
#  'got something mind',
#  '',
#  '',
#  "well 's someone think might",
#  'little find wench date plan progressing',
#  'forget',
#  "'s 's nice one",
#  "n't want know say though want know useful thing like good store much champagne cost stuff like chat never life point someone",
#  "right see 're ready quiz",
#  "c'esc tete",
#  'let see',
#  'gosh could find',
#  "'s shame",
#  'unsolved mystery used really popular started high school like got sick something',
#  '',
#  'seems like could get date easy enough',
#  "thing 'm mercy particularly hideous breed loser ca n't date",
#  '',
#  "'s fault n't proper introduction",
#  'forget',
#  "'re asking 's cute 's name",
#  "okay 'bout try cuisine saturday night",
#  'hacking gagging spitting part please',
#  "well thought 'd start pronunciation 's okay",
#  'make quick korrine barrett incredibly horrendous public break quad',
#  '',
#  "think ' prom",
#  "n't home 'til two",
#  'home twenty minute',
#  "know 'd give private line go like",
#  "sometimes wonder guy 're supposed want go one actually want go know",
#  "n't think highlight dating dorsey going include door opening coat holding",
#  "combination n't know thought 'd different",
#  'oily dry',
#  "practically proposed found dermatologist mean dr bonchowski great 's exactly relevant party conversation",
#  'would mind getting drink',
#  'great',
#  '',
#  '',
#  'go',
#  'might wan na think',
#  '',
#  'change hair',
#  "know deal ' go n't go",
#  'listen want talk prom',
#  "'re concentrating awfully hard considering 's gym",
#  'hi',
#  'hey sweet cheek',
#  "say 've got good shot prada next year",
#  'neat',
#  "'s gay cruise line 'll like wearing uniform stuff",
#  '',
#  "yeah 've got sears catalog thing going tube sock gig 's gon na huge 'm ad next week",
#  'hopefully',
#  "exactly going bogey lowenbrau 's thing saturday",
#  'expensive',
#  "'s",
#  'perm',
#  '',
#  "'s",
#  'complete fruit loop',
#  'wanted',
#  'completely damage send therapy forever',
#  'wanted',
#  'set',
#  'let go',
#  '',
#  'looked beautiful last night know',
#  "guess 'll never know",
#  "experience good ca n't always trust people want",
#  "'re like keep locked away dark ca n't experience anything",
#  'guess thought protecting',
#  "'m stupid enough repeat mistake",
#  "'s",
#  "n't really thought could make decision would 've let go instead helping hold hostage",
#  'wanted let make mind',
#  "n't tell",
#  "swore 'd never anything everyone else n't since except bogey 's party stunning gastro intestinal display",
#  '',
#  "afterwards told n't want anymore n't ready got pissed broke",
#  '',
#  'said everyone',
#  '',
#  'back different story',
#  'hate',
#  'like total',
#  '',
#  '9th month',
#  '',
#  'never told went',
#  "wish luxury 'm got asked prom ca n't go '",
#  "care 'm firm believer something reason someone else '",
#  'like care',
#  "listen know hate sit home 'm high school",
#  "'re welcome",
#  "n't get act like 're good go totally apeshit get",
#  "really n't think need social advice right",
#  'need talk need tell',
#  'go',
#  'completely unbalanced',
#  "yeah 's freak friend 's guess since 'm allowed go ob dead",
#  "'s shakespeare maybe 've heard",
#  "like 'm supposed know even mean",
#  "least 'm clouted fen sucked hedge pig",
#  "ca n't forget one night 're completely wretched",
#  "bogey 's party 're busy listening bitch need prozac know",
#  "'s",
#  "'re ruining life ' wo n't ca n't",
#  "think 're freak think torture think suck",
#  'think',
#  "oh thought might date n't know 'm bothering ask going bogey 's party saturday night",
#  "mean gigglepuss playing club skunk 're going",
#  "oh mean 're becoming",
#  'least start wearing bra',
#  "potential smack crap n't get way",
#  'nowhere hi',
#  "'ve",
#  "date ' oppression like men know",
#  "'m missing something",
#  "fine see 'm house 'm 'm possession",
#  "'re going unless go end story",
#  "'s hot whatever",
#  "'s hot right ' want bend rule",
#  '',
#  'prom date',
#  "want discus prom 's tomorrow night",
#  "'ll scare away",
#  '',
#  "promise wo n't talk unless present",
#  'minute',
#  '',
#  'wear belly go',
#  "'s party",
#  "oh 's starting",
#  "'s going 're going",
#  'people expect',
#  "'s party knew 'd forbid go since steinem n't going",
#  'otherwise known orgy',
#  'must know attempting go small study friend',
#  "'re going",
#  '',
#  'exactly point',
#  "n't want date",
#  "'s fair 's mutant",
#  "neither 'll get sleep night",
#  'never start dating',
#  "'re dating start dating end discussion",
#  "n't get upset 's think might ask",
#  "sent 'em",
#  'padua girl one tall decent one kinda short undersexed',
#  'never',
#  'fan fan see couple minor come',
#  "n't pegged gigglepuss fan n't little pre teen belly button ring",
#  'always pleasure brucie',
#  "best scenario 're back payroll awhile",
#  'humiliated sacrifice altar dignity even score',
#  "'",
#  "buttholus extremus hey 're making progress",
#  "hell kind 'guy pick carry away 're talking",
#  'extremely unfortunate maneuver',
#  "hell 've going whole thing",
#  'told part already',
#  "'s favorite",
#  'assail ear one night',
#  "okay n't sure",
#  "'s pretty",
#  'dead forty one',
#  'favorite',
#  "'s lung cancer issue",
#  'number one hate smoker',
#  "kidding 'll piss joy 's ultimate kiss as",
#  'bogey get bent',
#  "'ll need make school wide blow",
#  'golden opportunity ask katarina party',
#  "like choice besides let enemy think 's orchestrating battle 're position power let pretend 's calling shot 's busy setting plan time",
#  'got involved',
#  "hey 've got ta client get wall street",
#  'thought hated people',
#  "know go 'd set 'd outrank everyone strictly list side",
#  "'s said",
#  "actually say 'd go",
#  "forget reputation think 've got plan",
#  "'m serious 's whacked sold liver black market could buy new speaker",
#  'always let felon sit honor biology',
#  "kidding 's criminal heard lit state fire got alcatraz",
#  'seems like thrives danger',
#  "make think 'll",
#  'wan na go',
#  '',
#  "unlikely even still ca n't go 's point",
#  'teach get know dazzle charm fall love',
#  'mewling rampalian wretch',
#  "'s 's",
#  'yeah minor encounter shrew',
#  'could consecrate friend',
#  "mean 'd get talk",
#  'guess signed tutor',
#  "sure 's canada",
#  'know',
#  "dorsey perma shit grin wish could say 's moron 's number twelve model mostly regional stuff 's rumored big tube sock ad coming",
#  'always shit eating grin',
#  "'re bred mother liked guy like grandmother pool rarely diluted",
#  'girl like always like guy like',
#  "could start haircut n't matter 's allowed date older 's impossibility",
#  '',
#  "stratford n't even think",
#  '',
#  'burn pine perish',
#  '',
#  'yeah guy never seen horse clint eastwood',
#  "'m used",
#  'couple thousand evil',
#  'many people go',
#  'get',
#  'thirty two',
#  'many people old school',
#  "yeah couple 're outnumbered cow though",
#  'kidding people actually live',
#  "north actually 'd",
#  'dakota',
#  "c'mon 'm supposed give tour",
#  'tell',
#  'new',
#  'get',
#  "'s worst",
#  '',
#  'kissed',
#  "makin ' headway",
#  "need time cool 'll give day",
#  "hate fire thousand sun 's direct quote",
#  "' know decided nail drunk remember",
#  "'d",
#  'go get',
#  'sure',
#  'like',
#  "'s partial",
#  "'re talking",
#  "'s whole thing",
#  "'m little busy",
#  "n't make",
#  'gigglepuss playing tomorrow night',
#  "give 'm supposed buy noodle sit around listening chick ca n't play instrument",
#  'okay like food feminist prose angry stinky music indie rock persuasion',
#  "'ve retrieved certain piece information miss katarina stratford think 'll find helpful",
#  "'ve got",
#  "yeah 'll see",
#  'mean strictly non prison movie type way',
#  'would',
#  'leave alone',
#  '',
#  'away',
#  'ya goin',
#  '',
#  'hey mind',
#  "'re running rest next month",
#  'yeah noticed part featured big kmart spread elbow tough break',
#  "vintage look n't reading sassy",
#  "enough barbie n ' shit know",
#  "n't know dorsey limo flower another hundred tux",
#  'get act like human',
#  '',
#  "'d",
#  "deal 's deal",
#  "'s time",
#  'forget',
#  'forget',
#  'hundred buck date',
#  '',
#  'upped',
#  'got control act crazed public keep image',
#  "watching bitch trash car n't date",
#  "'m",
#  'shell fifty expect result',
#  "fifty 've got",
#  "take leave n't negotiation",
#  'fine thirty',
#  "ca n't take like twenty buck",
#  'much',
#  "ca n't date one get 's catch n't want",
#  "'re gon na pay take",
#  'got verona pick tab honor',
#  "'d go cake",
#  'need money take',
#  'said',
#  "sure sparky 'll get right",
#  'yeah whatever want go',
#  'two leg nice rack',
#  'think',
#  'yeah',
#  "hey 's higher good right",
#  "better fuck 'm heavily invested",
#  'took bathe together',
#  'verona',
#  "uh yeah 're old friend",
#  "hear 're helpin ' verona",
#  "need recruit 'll go someone 's job",
#  'conversation purpose',
#  "ca n't go insane one go right",
#  "'re",
#  "well actually thought 'd run idea know see 're interested",
#  "n't chat",
#  'nope came chat',
#  'lost',
#  'hey',
#  "oh tell n't ' progressed full hallucination",
#  'asked meet',
#  '',
#  'seen',
#  'oh good something new different u',
#  "' looking wrong perspective 're making statement",
#  "okay okay wo n't go 's like dress anyway",
#  'listen sound like pissed taking',
#  "well guess 're since n't date",
#  'even imagine hell would go bastion commercial excess',
#  'got drunk puked got rejected big fun',
#  "n't",
#  'favor backfired',
#  "n't choice 's done",
#  "n't choice",
#  'went party thought officially opposed suburban social activity',
#  'care',
#  "'d say",
#  'fear',
#  "think 'll work",
#  "would school want precious n't forget tiara",
#  'matter',
#  "appreciate effort toward speedy 'm consuming mind",
#  'neither heterosexuality',
#  "'s never proven",
#  "n't even go high school",
#  'would never gone state school',
#  'huge raging fit insists go male dominated puking frat number one golf team school say',
#  "could always go 'm sure friend",
#  'people school incredibly foul',
#  "imagine thing 'd say sex",
#  "realize men fine institution severely lacking killing shakespeare beyond scope teenage obsession 're venturing far past daytime talk show fodder entering world need expensive therapy",
#  'attempted slit',
#  "'s",
#  'little',
#  'eat starving slow way die',
#  'block e',
#  'always look',
#  "'m sure 's completely incapable anything interesting",
#  "'s verona one gone year heard porn movie",
#  'verona random skid',
#  "'s",
#  "' even dare",
#  'oh get freshman yearbook',
#  'like torture',
#  'veggie burger burnt object grill',
#  'yeah fucked',
#  'right',
#  'besides extra asshole paid take really great',
#  'thought could use start',
#  'fender strat bought',
#  "n't care money",
#  'really like payment bonus sleeping',
#  "n't like",
#  'paid take one person truly hate knew set',
#  'wait',
#  'get worse still freshman yearbook',
#  "' completely adorable",
#  "'s last year 'd never lived alone died stayed n't jail n't know marilyn manson 've never slept spice spent year sitting next couch watching wheel fortune end story",
#  '',
#  "'s",
#  "look 'm sorry questioned motif wrong",
#  'oh huh',
#  "'s something know",
#  "'s scurvy 's date got convicted 'd get dress",
#  "'d get tux last minute",
#  "nothing 's nothing pleasure company",
#  'answer question',
#  'need therapy anyone ever told',
#  'tell',
#  'motive',
#  'create little drama start new rumor',
#  "n't want 's stupid tradition",
#  '',
#  "wo n't go",
#  '',
#  '',
#  'know mean',
#  'request command',
#  'go prom',
#  "'re amazingly self assured anyone ever told",
#  'one else know',
#  '',
#  "'re sweet sexy completely hot",
#  'something real something one else know',
#  'hate pea',
#  'tell something true',
#  "know porn career 's lie",
#  'hearsay',
#  'duck',
#  'fallacy',
#  'state',
#  '',
#  '',
#  'never disappointed',
#  '',
#  'screwed',
#  'something like',
#  "disappoint start 're covered",
#  "n't like people expect expect time get disappointed change",
#  'yes',
#  'acting way',
#  "'s excuse",
#  "yeah well n't let get",
#  'soft side knew',
#  'dazzled wit',
#  "'d get chapin look way",
#  'good call',
#  'figured something ridiculous respect piss',
#  'partridge',
#  'maybe',
#  'want climb show get',
#  "forget 'm stayin '",
#  'put right foot',
#  "try lookin '",
#  "c'mon 's bad",
#  "guess never told 'm afraid height",
#  'look',
#  'left sprung dickhead cruised',
#  'upchuck reflex nothing',
#  'effect',
#  "n't one minute think effect whatsoever panty",
#  'unwelcome guess someone still panty',
#  'unwelcome',
#  'wholesome',
#  'pleasant',
#  "'re",
#  'heard poetry reading',
#  '',
#  'excuse seen feminine mystique lost copy',
#  "offense 're without know everyone like",
#  '',
#  '',
#  "want someone 'm",
#  "' pain as",
#  "'m gettin '",
#  'oh think know',
#  "n't strike type would ask permission",
#  "would n't approve",
#  'start',
#  '',
#  '',
#  '',
#  "'d lie",
#  "'d ask",
#  "n't",
#  'maybe',
#  'jail',
#  'busy',
#  'gone last year',
#  "'s gigglepuss know like saw",
#  "'m control",
#  '',
#  'wake',
#  'know say',
#  'thought',
#  "hey ' think cool n't think laid back like everyone else",
#  "know 'd pretty big deal get mainline tequila n't seem like type",
#  'hate',
#  'dorsey',
#  '',
#  "'d let get",
#  'let sit',
#  "see need affection 've got blind hatred",
#  'like could find one',
#  "'d start taking girl like",
#  '',
#  'sure',
#  "n't care die",
#  'told',
#  "'re",
#  "leave use big word 're shitfaced",
#  'patronizing',
#  'concussion went sleep concussion woke vegetable could tell difference',
#  'know let sleep',
#  "uh uh lie 'll go sleep",
#  'need lie awhile',
#  "'re okay",
#  "'m fine 'm",
#  'okay',
#  "funny 're one",
#  'say wan na',
#  "'m getting trashed n't 're supposed party",
#  "'s",
#  "n't",
#  'know raincoat',
#  "know guy bikini kill raincoat 're right",
#  "mind 're sort ruining",
#  "'s want n't",
#  'excuse',
#  'hey great show huh',
#  "depends topic fender n't really whip frenzy",
#  "'re big talker",
#  'hi',
#  "laundromat saw car thought 'd say hi",
#  'following',
#  'seven thirty',
#  'covered vomit',
#  'come pony flat beer money eye as',
#  'would',
#  "say 'll spend dollar night track",
#  "n't really think warrant strong emotion",
#  "hate n't",
#  'know lot',
#  'like 7 eleven burnside even know name screwboy',
#  "night take place 've never back",
#  'oh right friday',
#  'pick friday',
#  'mission life',
#  "'s way get 's attention",
#  'sweating like pig actually',
#  "mean wo ya doin '",
#  "oh christ n't tell 've changed mind already sent 'em check",
#  'go',
#  "know father n't like admit daughter capable running life mean 've become spectator still let play inning 've bleacher year go wo n't even able watch game",
#  'impressed',
#  "'s matter upset rubbed",
#  '',
#  'part beat hell',
#  'part',
#  'part',
#  'tell dance fun',
#  '',
#  "n't understand allure dehydrated food something hip",
#  'funny',
#  'yeah left bikers big one full sperm',
#  '',
#  'want go east coast school want trust make choice want',
#  "'re eighteen n't know want wo n't know 're forty five n't",
#  "want n't matter",
#  "parent 's right",
#  "'re making decision",
#  "ca n't agree",
#  'thought punishing',
#  'punishing',
#  'tell seizure',
#  'insurance cover pm',
#  'enough',
#  'someone whose diary devoted favorite grooming tip',
#  'decided',
#  'thought decided going school u 0',
#  'know',
#  'smack',
#  'supposed feel better like right time think',
#  'believe heinous bitch term used often',
#  'tempestuous',
#  'point people perceive somewhat',
#  'still maintain kicked ball merely spectator',
#  "well yes compared choice expression year today 's event quite mild way rictor 's gonad retrieval operation went quite well 're interested",
#  'expressing opinion terrorist action',
#  "katarina stratford 've terrorizing m blaise",
#  'yeah',
#  'fan',
#  'right',
#  'macbeth right',
#  'oh yeah',
#  'think',
#  'yeah guess',
#  'cool picture fan',
#  'hi',
#  'hey tired breathing',
#  "n't say shit like people hear",
#  'sweet love renew thy force',
#  "right 's still pissed",
#  "'ve got sweet payin ' job 'm lose",
#  'got cozy sting',
#  "'m likin ' guy better",
#  'prefer think simply alternative law allows',
#  'yeah',
#  'ever club skunk',
#  '',
#  "telling 'm non smoker",
#  'good enough',
#  '',
#  "'re guy",
#  'two gon na help tame wild',
#  "'re looking big picture 's pawn set whole thing get",
#  'dorsey get',
#  "'s help",
#  "dorsey plow whoever want 'm",
#  "think speak correctly say 's love pure purer say dorsey 's",
#  'three tit',
#  'situation stratford',
#  'plan',
#  "whatever hell 're standin ' waitin ' say",
#  '',
#  'say',
#  'see next week',
#  "'re completely demented",
#  "well know 's prestige job title benefit package pretty good",
#  "n't abused n't stupid far tell 're slightly psychotic 're fuck",
#  "'s discus",
#  "n't discus driving need hemorrhoid",
#  "'m loss talk year absence",
#  'touch flu',
#  "n't understand n't done anything asinine week feeling well",
#  'teeth zipper',
#  'bratwurst eating lunch',
#  'say exposed freshman girl',
#  'missed',
#  "' thought",
#  'absolutely',
#  'anything say',
#  'daughter went prom',
#  'happened',
#  '',
#  'great time',
#  'dr',
#  "wan na watch 've got crap crap crap crap",
#  "kissing think happens kissing n't keep elbow placenta day",
#  "'ll dance 'll kiss 'll come home let go",
#  'pirate question',
#  'would rather ravished pirate british rear',
#  "'re helping",
#  'tumescent',
#  'even grab sandwich woman start dilating',
#  'side country',
#  "'s synonym throbbing",
#  'make anyone cry today',
#  'microwave',
#  "ca n't far say also n't like smell sea around smell like cunt bad sign",
#  "left three week ago ca n't near",
#  'seen land',
#  "'ll go crazy",
#  "'s devil 's",
#  "face like n't want looking hear",
#  "ah leave alone 's harm",
#  'listening chicken as',
#  "'ll drinking piss glory spain colon bastard",
#  "water 's going putrid barrel",
#  'never seen heat like even la mina',
#  'will',
#  'asia found prove',
#  'blind consider heresy',
#  "n't realize word could considered heretical",
#  "choose 's son reveal world",
#  'intended proximity asia believe would waited show world',
#  'portuguese already discovered black skinned people find population bring word',
#  'interest',
#  'trade excellency according marco kingdom one richest world even meanest building roofed',
#  'agree follow yes',
#  'life others',
#  'eminence one way settle matter make journey ready risk life prove possible',
#  'excellency right',
#  'senor colon experienced understand concern crew willing conscience loss men would relied upon judgment',
#  'ignore according calculation circumference earth approximately 22000 league make ocean uncrossable',
#  'eminence',
#  'unfortunately colon precisely opinion differ familiar work aristotle erathostene ptolemeus',
#  'yes eminence voyage take six seven week',
#  'say asia found sailing',
#  'waste let tell something name mine ever remembered',
#  'tragedy waste life',
#  'see',
#  'contrary eminence seems preparing',
#  "wo n't easy get rid prophet",
#  'indeed world full mercenary state often make use benefit concern welfare prosperity spain',
#  'mercenary already try convince portugal absurd notion',
#  'naturally would really deplore loss potential opportunity spain dispute point geography',
#  'judgment',
#  "state reason interested 's proposition eminence",
#  "ca n't keep eye would like catch moment n't spend",
#  'tell',
#  'busy inside',
#  "ca n't stay u little",
#  "everything think care 'm free rich n't make rich make busier",
#  'took everything',
#  "tried n't let",
#  "'re beautiful ca n't believe ever taken away",
#  'arrange take service',
#  "n't usually ask",
#  'want ask something',
#  "'s something ca n't decide",
#  "n't want wait",
#  "'m asking swear anything",
#  'thank',
#  'said yes',
#  'find hard believe',
#  'perhaps never meant live',
#  "'d love argue sometimes 're never",
#  'going argue',
#  "well 's true wo n't marry 's always leaving",
#  "n't given much life",
#  'know',
#  'could gone year',
#  'afraid worst news',
#  'could mainland found exactly said would',
#  'seaman heard week sea disappointed',
#  'far',
#  'congratulation free search mainland',
#  'indie',
#  'appointment',
#  'letter appointment',
#  'yes remember',
#  'de',
#  'bartolome giacomo colon',
#  'ask',
#  'forgive position already taken',
#  'understand soon appointing governor island',
#  'tell first thing come mind',
#  "really would n't know start yet",
#  'want tell everything remember beginning everything',
#  'never one except aboard ship',
#  'asks come visit left address',
#  'say',
#  "listening ca n't help hearing",
#  'listening',
#  'must passage ocean',
#  '',
#  'bad',
#  'feeling',
#  'time',
#  'explore mainland',
#  'yes yes',
#  'swear holy saint heaven',
#  'promise swear st christopher',
#  "'ll time",
#  'want go',
#  'created people like',
#  'roof tower palace spire',
#  'see',
#  'look window',
#  'afraid nothing dreamer',
#  'call',
#  'call guard',
#  'rise high short time dangerous occupation little hypocrisy go way',
#  'many already',
#  'seem special talent making friend',
#  'good also need judge except thief',
#  'already dear cristobal',
#  'lack notary contact administration',
#  'commoner',
#  'defend admirably',
#  'forgive colon',
#  "n't see sin nakedness live according nature never ending summer island covered tree filled blossom fruit",
#  "wo n't accept proposal 'll simply find someone",
#  'never ambitious excellency ambition virtue among noble fault rest u',
#  'ambitious',
#  "'m bargaining",
#  'remind senor colon position bargain',
#  'waited fought hard expect take risk take profit',
#  '',
#  '',
#  'never learned speak language',
#  "wo n't speak used know speak",
#  '',
#  'find look',
#  'ask help',
#  'understands',
#  'work people want peace ask understands',
#  'medicine tell admire people',
#  'say',
#  'also bring medicine',
#  'say',
#  'bring word',
#  '',
#  'thousand',
#  'say many',
#  'tell country beautiful tell leaving men build fort',
#  'know',
#  'tell thank',
#  'come speak first',
#  'island far',
#  'tribe island',
#  'say cuba',
#  "n't know impression n't change much still ca n't accept world",
#  'oh new',
#  'new world create new people',
#  'knew would',
#  'disagree',
#  "'ll always older",
#  "suppose 're old men",
#  'give absolution',
#  'believed',
#  'bound oath',
#  "son son certitude sometimes frightening christopher must speak n't",
#  "tell wo n't follow know right trust",
#  'forgive must tell must tell men',
#  'sure could twice distance',
#  '',
#  'lied journey longer said',
#  'saying',
#  'betrayed betrayed men betrayed',
#  'listening son',
#  'forgive sinned',
#  'nomine patris et filius et spiritus sancti',
#  "colon n't",
#  'lie',
#  'damn set theory based never leave safety study go find world tell something listen',
#  'colon',
#  'damn',
#  'intends go go',
#  "wait 've waited seven year already much longer want wait",
#  "must n't give way despair must wait",
#  'know meaning word son',
#  "'ve contradicted life eternity",
#  'get carried away contradicted',
#  'passion something one control',
#  '',
#  "'ll try remember",
#  "two minute already 're dead n't let passion overwhelm colon",
#  'christ',
#  'esdras jew',
#  'calculation toscanelli marin de tyr esdras',
#  'certain',
#  'ignorance believe indie 750 league canary island',
#  'certain ocean said infinite',
#  'open new route asia moment two way reaching',
#  'wish sail',
#  'difficulty promise total fool',
#  'manage',
#  "'s say",
#  "'s week",
#  'think best would chosen',
#  'bright pleasure teach serious brother raised together colon even brother different mother',
#  'majesty men content read thing must see eye',
#  "one thing 'd like understand want go back",
#  'thank',
#  'without brother return santo domingo colony explore continent',
#  'come go naked day created',
#  'thought',
#  'thirty seven majesty',
#  'old senor colon',
#  '',
#  "know see see someone n't accept world 's afraid see woman think",
#  'show inclination speak otherwise',
#  'speak freely',
#  'surely anything want',
#  'ignore verdict council',
#  'impregnable',
#  'say granada today',
#  'ocean uncrossable',
#  'said would take granada moor',
#  'even listening since council said santangel tell honor sincerity fool',
#  'regret',
#  "'ll held detention deprived privilege possession returned spain judged anything say",
#  'savagery monkey understand',
#  'one act brutality created chaos tribe fighting joining force u criminal savagery',
#  'hear colon horse',
#  'work',
#  "horse n't work",
#  "ca n't raise wheel without",
#  'came stay build start crusade forest enough danger sweep u away day brave swallow grief name died accomplish came',
#  "n't need know",
#  'want war fine thousand outnumber u ten kill tribe',
#  "want keep shoulder 'll say",
#  'lost cousin friend wash blood',
#  'indian word',
#  "say indian vice n't see kind pleasure would make sin",
#  "ca n't",
#  "'s drawing isthmus 's saying 're isthmus",
#  "'s",
#  'twenty eight',
#  'read',
#  'come',
#  "well surely know quadrant 've never seen used night",
#  'think',
#  "well 's men sir wonder know position 've lost sight land day ago",
#  'u',
#  'due u',
#  "'re right let men decide",
#  'tell',
#  'go forward think',
#  'bloody',
#  'never talking u remember',
#  'never listened',
#  'half water gone rest nearly putrid know',
#  "n't know anything listen colon ship right 'm telling 're turning back",
#  'land know',
#  "'re lost",
#  "think n't know",
#  "'re verge mutiny colon",
#  'keep hope men alive',
#  'must mad',
#  'six day ago yes',
#  "lied cheated 're way past 750 league",
#  'immediately',
#  'meet',
#  'afraid',
#  '',
#  'know tolerate impertinence',
#  'would think task',
#  'must replaced',
#  'suggest',
#  'true buyl',
#  'worse ordered execution five member nobility',
#  "n't expecting immediate profit must must give time time",
#  'every ship return cargo sick dying new world prof expensive majesty',
#  "yes would pity would n't call back",
#  '',
#  'never majesty although',
#  'right demand could never granted',
#  'yes majesty',
#  'knew treasurer',
#  "officer 's duty arrest",
#  'kill someone famous caught sent mental hospital',
#  "n't think 's abuse think 's torture",
#  "'m abused n't think",
#  'see back',
#  'back small',
#  'put cigarette',
#  "'s put cigarette",
#  'yeah hated day born put put cigarette',
#  "blamed 's blindness",
#  'yeah yeahbad gave bad drug made go blind blamed blindness',
#  'back czech republic',
#  'yeah went blind giving birth went fucking black market induce',
#  'blind',
#  'always degraded killed self esteem blind',
#  'tell young parent like',
#  'give another one please',
#  "need know background need know upbringing 're",
#  'else need',
#  'money need trust',
#  "thirty percent call another biggest life n't try negotiate thirty percent say yes",
#  "'s",
#  'way',
#  'would sayhalf half fair',
#  "'s cut much",
#  "look n't really focused kind thing",
#  'movie right right',
#  "n't worry think",
#  'shit',
#  "disappeared 're looking everywhere maybe went back czechoslovakia",
#  '',
#  "well n't appreciate severity recently question",
#  '',
#  'delusion paranoia',
#  'oh sure',
#  'bring cigarette',
#  "brought letter 's really fan mail woman mostly one want buy clothes another sent check another want check",
#  "'m invoking right represented 'm coming",
#  'yes yes come',
#  "'m coming",
#  'going',
#  "n't say anything",
#  'camera took movie',
#  'take easy stay sit need looking',
#  'oh shit',
#  'money',
#  "'m see money",
#  "'m 'm insane",
#  '',
#  "n't want drag",
#  'really want forget',
#  'forget enough problem',
#  'pouring',
#  '',
#  "'ll get clothes",
#  "'ll make u",
#  'kitchen',
#  'coffee',
#  'right',
#  ...]

# %%
 #Create a dataframe from the list and save it as a csv
dialogue_df = pd.DataFrame(dialogue_list, columns=['Dialogue'])
dialogue_df.to_csv('dialogue_list.csv')

# %% [markdown]
# # Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer
#we can define max_features 
max_features = 1000
count_vectorizer = CountVectorizer(max_features=max_features,stop_words = "english")
#count_vectorizer = CountVectorizer(stop_words = "english")

sparce_matrix = count_vectorizer.fit_transform(dialogue_list).toarray() # x

print("{} most common words: {}".format(max_features,count_vectorizer.get_feature_names()))
# Out:
# 1000 most common words: ['able', 'absolutely', 'accept', 'accident', 'account', 'act', 'acting', 'action', 'actually', 'address', 'admit', 'advice', 'afford', 'afraid', 'afternoon', 'age', 'ago', 'agree', 'ah', 'ahead', 'ai', 'air', 'alive', 'alright', 'american', 'angry', 'answer', 'anybody', 'anymore', 'apart', 'apartment', 'apologize', 'appreciate', 'area', 'arm', 'army', 'arrest', 'ask', 'asked', 'asking', 'asleep', 'asshole', 'attack', 'attention', 'aw', 'away', 'awful', 'aye', 'bad', 'bag', 'ball', 'bank', 'bar', 'bastard', 'bathroom', 'beach', 'beat', 'beautiful', 'beauty', 'bed', 'beer', 'beg', 'begin', 'beginning', 'believe', 'best', 'bet', 'better', 'big', 'bird', 'birthday', 'bitch', 'bite', 'black', 'blame', 'blind', 'block', 'blood', 'blow', 'blue', 'board', 'boat', 'bomb', 'book', 'born', 'bother', 'bottle', 'bought', 'bout', 'brain', 'break', 'breakfast', 'breath', 'bridge', 'bring', 'broke', 'broken', 'brother', 'brought', 'buck', 'build', 'building', 'built', 'bullet', 'bullshit', 'bunch', 'burn', 'bus', 'business', 'busy', 'buy', 'bye', 'ca', 'california', 'called', 'calling', 'calm', 'came', 'camera', 'camp', 'car', 'card', 'care', 'career', 'careful', 'carry', 'cat', 'catch', 'caught', 'cause', 'cell', 'cent', 'century', 'certain', 'certainly', 'chair', 'change', 'changed', 'character', 'charge', 'cheap', 'check', 'chicken', 'child', 'choice', 'christ', 'cigarette', 'city', 'client', 'clock', 'close', 'closed', 'clothes', 'club', 'code', 'coffee', 'cold', 'college', 'color', 'come', 'comin', 'coming', 'command', 'common', 'company', 'complete', 'completely', 'concerned', 'condition', 'consider', 'contact', 'contract', 'control', 'conversation', 'cool', 'cop', 'copy', 'corner', 'correct', 'cost', 'country', 'couple', 'course', 'court', 'cousin', 'cover', 'crap', 'crazy', 'credit', 'crew', 'crime', 'criminal', 'cup', 'cut', 'cute', 'damn', 'dance', 'danger', 'dangerous', 'dark', 'darling', 'date', 'day', 'dead', 'deal', 'dear', 'decide', 'decided', 'decision', 'deep', 'definitely', 'department', 'desk', 'destroy', 'devil', 'die', 'died', 'difference', 'different', 'difficult', 'dig', 'dinner', 'dirty', 'discus', 'doin', 'dollar', 'donâ', 'door', 'double', 'doubt', 'dr', 'dream', 'dress', 'drink', 'drinking', 'drive', 'driving', 'drop', 'dropped', 'drug', 'drunk', 'dumb', 'dunno', 'duty', 'dying', 'ear', 'earth', 'easy', 'eat', 'eating', 'egg', 'eh', 'em', 'emergency', 'end', 'enemy', 'english', 'enjoy', 'entire', 'er', 'escape', 'especially', 'evening', 'event', 'everybody', 'evidence', 'evil', 'exactly', 'excuse', 'expect', 'experience', 'explain', 'extra', 'eye', 'face', 'fact', 'fair', 'fall', 'famous', 'far', 'fast', 'fat', 'fault', 'favor', 'favorite', 'fbi', 'fear', 'feed', 'feel', 'feeling', 'fella', 'fellow', 'felt', 'field', 'fight', 'fighting', 'figured', 'file', 'film', 'finally', 'fine', 'finish', 'finished', 'fired', 'fish', 'fit', 'fix', 'flight', 'floor', 'flower', 'fly', 'folk', 'follow', 'following', 'food', 'fool', 'foot', 'force', 'forever', 'forget', 'forgive', 'forgot', 'form', 'forward', 'free', 'friend', 'fuck', 'fucked', 'fuckin', 'fucking', 'fun', 'funny', 'future', 'game', 'gas', 'gave', 'gee', 'gentleman', 'gettin', 'getting', 'ghost', 'gift', 'gim', 'girl', 'girlfriend', 'given', 'giving', 'glad', 'goddamn', 'goin', 'going', 'gon', 'gone', 'good', 'goodbye', 'goodnight', 'got', 'gotten', 'government', 'grab', 'grand', 'great', 'greatest', 'ground', 'grow', 'guess', 'gun', 'guy', 'ha', 'hair', 'half', 'hall', 'hand', 'handle', 'hang', 'hanging', 'happen', 'happened', 'happening', 'happens', 'happy', 'hard', 'hardly', 'hat', 'hate', 'head', 'hear', 'heard', 'heart', 'heaven', 'heavy', 'heh', 'hell', 'hello', 'help', 'helped', 'hero', 'hey', 'hi', 'hide', 'hiding', 'high', 'history', 'hit', 'hold', 'holding', 'hole', 'holy', 'home', 'honest', 'honor', 'horse', 'hospital', 'hot', 'hotel', 'hour', 'house', 'huh', 'human', 'hungry', 'hurry', 'hurt', 'husband', 'idea', 'idiot', 'imagine', ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
# list of the text documents
text = dialogue_list
vectorizer = CountVectorizer()
#tokenize and build vocab
vectorizer.fit(text)
#summarize
print(vectorizer.vocabulary_)
#encode doc
vector = vectorizer.transform(text)
#summarize encoded vector
print(vector.shape)
print(type(vector))
print(vector.toarray())
# Out:
# {'okay': 27936, 'let': 22958, 'go': 16475, 'wow': 46070, 're': 32292, 'gon': 16601, 'na': 26508, 'need': 26751, 'learn': 22779, 'lie': 23064, 'kidding': 21777, 'know': 21996, 'sometimes': 36982, 'become': 4074, 'persona': 29682, 'quit': 31879, 'like': 23159, 'fear': 14279, 'wearing': 45037, 'pastel': 29217, 'real': 32328, 'good': 16622, 'stuff': 38355, 'figured': 14538, 'get': 16183, 'eventually': 13513, 'thank': 39734, 'hear': 17913, 'one': 28069, 'story': 38149, 'coiffure': 8033, 'endless': 13008, 'babble': 3419, 'boring': 5208, 'crap': 9331, 'listen': 23291, 'guillermo': 17209, 'say': 34559, 'lighter': 23135, 'look': 23564, 'extra': 13870, '90210': 787, 'always': 1965, 'selfish': 35140, 'well': 45143, 'never': 26902, 'wanted': 44796, 'me': 24753, 'looked': 23569, 'back': 3463, 'party': 29173, 'seemed': 35077, 'occupied': 27717, 'ton': 40587, 'fun': 15720, 'tonight': 40598, 'believe': 4235, 'share': 35466, 'instructor': 20325, 'thing': 39991, 'worked': 45971, 'huh': 19015, 'hi': 18304, 've': 44114, 'ever': 13516, 'heard': 17914, 'dip': 11164, 'dating': 10063, 'smoke': 36616, 'kind': 21834, 'pretty': 31033, 'lesbian': 22942, 'found': 15304, 'picture': 29953, 'jared': 21068, 'leto': 22965, 'drawer': 12031, 'sure': 38782, 'harboring': 17649, 'sex': 35356, 'tendency': 39579, 'workin': 45980, 'seem': 35075, 'goin': 16559, 'really': 32347, 'wan': 44776, 'ca': 6161, 'unless': 42946, 'eber': 12482, 'deep': 10334, 'conditioner': 8500, 'every': 13524, 'two': 41512, 'day': 10097, 'use': 43511, 'blowdryer': 4880, 'without': 45827, 'diffuser': 11056, 'attachment': 3123, 'hair': 17416, 'sweet': 38958, 'word': 45956, 'counted': 9165, 'help': 18089, 'cause': 6813, 'thug': 40226, 'obviously': 27702, 'failing': 14005, 'going': 16561, 'date': 10059, 'got': 16702, 'something': 36967, 'mind': 25373, 'someone': 36952, 'think': 40019, 'might': 25275, 'little': 23329, 'find': 14601, 'wench': 45215, 'plan': 30187, 'progressing': 31252, 'forget': 15200, 'nice': 26981, 'want': 44792, 'though': 40134, 'useful': 43523, 'store': 38135, 'much': 26236, 'champagne': 7027, 'cost': 9113, 'chat': 7150, 'life': 23090, 'point': 30419, 'right': 33601, 'see': 35054, 'ready': 32322, 'quiz': 31892, 'esc': 13345, 'tete': 39707, 'gosh': 16699, 'could': 9140, 'shame': 35435, 'unsolved': 43123, 'mystery': 26489, 'used': 43518, 'popular': 30596, 'started': 37821, 'high': 18336, 'school': 34724, 'sick': 35940, 'seems': 35084, 'easy': 12457, 'enough': 13108, 'mercy': 25037, 'particularly': 29157, 'hideous': 18322, 'breed': 5486, 'loser': 23630, 'fault': 14228, 'proper': 31325, 'introduction': 20529, 'asking': 2923, 'cute': 9793, 'name': 26559, 'bout': 5294, 'try': 41282, 'cuisine': 9672, 'saturday': 34500, 'night': 27025, 'hacking': 17371, 'gagging': 15822, 'spitting': 37437, 'part': 29139, 'please': 30281, 'thought': 40135, 'start': 37820, 'pronunciation': 31311, 'make': 24106, 'quick': 31838, 'korrine': 22098, 'barrett': 3816, 'incredibly': 19876, 'horrendous': 18800, 'public': 31516, 'break': 5449, 'quad': 31749, 'prom': 31275, 'home': 18633, 'til': 40319, 'twenty': 41466, 'minute': 25442, 'give': 16350, 'private': 31125, 'line': 23225, 'wonder': 45899, 'guy': 17303, 'supposed': 38760, 'actually': 1204, 'highlight': 18347, 'dorsey': 11870, 'include': 19820, 'door': 11820, 'opening': 28201, 'coat': 7935, 'holding': 18594, 'combination': 8167, 'different': 11048, 'oily': 27923, 'dry': 12173, 'practically': 30798, 'proposed': 31338, 'dermatologist': 10703, 'mean': 24766, 'dr': 11990, 'bonchowski': 5076, 'great': 16928, 'exactly': 13585, 'relevant': 32888, 'conversation': 8869, 'would': 46054, 'getting': 16197, 'drink': 12083, 'change': 7050, 'deal': 10167, 'talk': 39226, 'concentrating': 8448, 'awfully': 3352, 'hard': 17650, 'considering': 8677, 'gym': 17324, 'hey': 18283, 'cheek': 7206, 'shot': 35780, 'prada': 30806, 'next': 26960, 'year': 46315, 'neat': 26724, 'gay': 16014, 'cruise': 9591, 'll': 23386, 'uniform': 42881, 'yeah': 46274, 'sears': 34982, 'catalog': 6753, 'tu ...
# (292943, 46804)
# <class 'scipy.sparse.csr.csr_matrix'>
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-130-79bf44341782> in <module>
#      12 print(vector.shape)
#      13 print(type(vector))
# ---> 14 print(vector.toarray())
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1022         if out is None and order is None:
#    1023             order = self._swap('cf')[0]
# -> 1024         out = self._process_toarray_args(order, out)
#    1025         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1026             raise ValueError('Output array must be C or F contiguous')
#
# ~\Anaconda3\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1184             return out
#    1185         else:
# -> 1186             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1187
#    1188
#
# MemoryError:

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = dialogue_list
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
plt.savefig('wordcloud_allg.png')

# %% [markdown]
# Create dataframes for each gender

# %%
female_df = slim_df
male_df
non_df

# %%
female_df = slim_df[slim_df.gender == '1']
female_df
# Out:
# Empty DataFrame
# Columns: [gender, dialogue]
# Index: []

# %% [markdown]
# # Split data into training and testing sets

# %%
#Split data into training and testing 

y = slim_df.iloc[:,0].values #male, female and non-gendered
x = sparce_matrix
# test train split
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.1, random_state = 42)

# %% [markdown]
# # Apply Machine Learning Algorithm

# %% [markdown]
# ### Naive Bayes

# %%
#Gaussian Naive Bayes 
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()

nb.fit(x_train,y_train)

print("accuracy: ",nb.score(x_test,y_test))
# Out:
# accuracy:  0.3257552483358935

# %%
y_pred = nb.predict(x_test)
y_true = y_test

from sklearn.metrics import confusion_matrix

cm_nb = confusion_matrix(y_true,y_pred)

sns.heatmap(cm_nb,annot=True,cmap="RdPu",fmt=".0f",cbar=False)
plt.show()
plt.savefig('GNB.png')

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators = 10, max_depth=10)

rf.fit(x_train,y_train)

print("accuracy: ",rf.score(x_test,y_test))
# Out:
# accuracy:  0.6387438129373614

# %%
y_pred = rf.predict(x_test)
y_true = y_test

from sklearn.metrics import confusion_matrix

cm_nb = confusion_matrix(y_true,y_pred)

sns.heatmap(cm_nb,annot=True,cmap="RdPu",fmt=".0f",cbar=False)
plt.show()
plt.savefig('RF.png')

# %%
y_pred
unique, counts = np.unique(y_pred, return_counts=True)

# %%
unique, counts # no predictions
# Out:
# (array([0], dtype=int64), array([29295], dtype=int64))

# %%
###

# %%
from sklearn.naive_bayes import MultinomialNB

mnb = MultinomialNB()

mnb.fit(x_train,y_train)

print("accuracy: ",mnb.score(x_test,y_test))
# Out:
# accuracy:  0.6365250042669397

# %%
y_pred = mnb.predict(x_test)
y_true = y_test

from sklearn.metrics import confusion_matrix

cm_nb = confusion_matrix(y_true,y_pred)

sns.heatmap(cm_nb,annot=True,cmap="RdPu",fmt=".0f",cbar=False)
plt.show()
plt.savefig('MNB.png')

# %%
y_pred
unique, counts = np.unique(y_pred, return_counts=True)

# %%
unique
# Out:
# array([0, 1, 2], dtype=int64)

# %%
counts
# Out:
# array([28276,   949,    70], dtype=int64)
